# %% [markdown]
# # **J057**
# # **Class 3: Using SPACY library to find nouns**

# %%
import pandas as pd
import spacy

# %%
data = pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz" , lines=True)

# %%
data.head()
# Out:
#        reviewerID        asin  ... unixReviewTime   reviewTime
# 0  A32T2H8150OJLU  B00000JBLH  ...     1094169600   09 3, 2004
# 1  A3MAFS04ZABRGO  B00000JBLH  ...     1197676800  12 15, 2007
# 2  A1F1A0QQP2XVH5  B00000JBLH  ...     1293840000   01 1, 2011
# 3   A49R5DBXXQDE5  B00000JBLH  ...     1145404800  04 19, 2006
# 4  A2XRMQA6PJ5ZJ8  B00000JBLH  ...     1375574400   08 4, 2013
#
# [5 rows x 9 columns]

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def SPACY(str):
    tokenization = []
    lemmatization = []
    pos_tags = []
    dependency_parser = []
    nouns = []
    doc = nlp(str)
    for word in doc:
        tokenization.append(word.text)
        lemmatization.append(word.lemma_)
        pos_tags.append(word.pos_)
        dependency_parser.append(word.dep_)
        if 'nn' in word.tag_.lower():
            nouns.append(word.text)
    return {'text': tokenization, 'lemma_': lemmatization, 'tag_': pos_tags, 'dependency parser': dependency_parser, 'nouns': nouns, 'noun_count': len(nouns)}

# %%
data.iloc[0:20]['reviewText'].apply(SPACY)
# Out:
# 0     {'text': ['I', 'bought', 'my', 'first', 'HP12C...
# 1     {'text': ['WHY', 'THIS', 'BELATED', 'REVIEW', ...
# 2     {'text': ['I', 'have', 'an', 'HP', '48GX', 'th...
# 3     {'text': ['I', ''ve', 'started', 'doing', 'mor...
# 4     {'text': ['For', 'simple', 'calculations', 'an...
# 5     {'text': ['While', 'I', 'do', 'n't', 'have', '...
# 6     {'text': ['I', ''ve', 'had', 'an', 'HP', '12C'...
# 7     {'text': ['Bought', 'this', 'for', 'my', 'boss...
# 8     {'text': ['This', 'is', 'a', 'well', '-', 'des...
# 9     {'text': ['I', 'love', 'this', 'calculator', '...
# 10    {'text': ['I', ''ve', 'had', 'mine', 'for', '4...
# 11    {'text': ['If', 'you', 'need', 'a', 'calculato...
# 12    {'text': ['A', 'great', ',', 'basic', 'calcula...
# 13    {'text': ['Texas', 'Instruments', 'makes', 'an...
# 14    {'text': ['This', 'review', 'is', 'for', 'the'...
# 15    {'text': ['This', 'is', 'a', 'well', 'built', ...
# 16    {'text': ['Texas', 'Instruments', 'Solar', 'Ca...
# 17    {'text': ['I', 'did', 'n't', 'take', 'math', '...
# 18    {'text': ['This', 'is', 'a', 'good', 'calculat...
# 19    {'text': ['Amazon', 'is', 'totally', 'my', 'sc...
# Name: reviewText, dtype: object
